# %% [markdown]
# <a href="https://colab.research.google.com/github/aayush1036/algorithm_trading_course/blob/master/Efficient_frontier/Efficient_frontier_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Efficient Frontier

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
ind = pd.read_csv('ind30_m_vw_rets.csv', header=0, index_col=0, parse_dates=True)/100

# %%
ind.head()
# Out:
#          Food    Beer    Smoke   Games  ...   Rtail   Meals   Fin     Other
# 192607  0.0056 -0.0519  0.0129  0.0293  ...  0.0007  0.0187  0.0037  0.0520
# 192608  0.0259  0.2703  0.0650  0.0055  ... -0.0075 -0.0013  0.0446  0.0676
# 192609  0.0116  0.0402  0.0126  0.0658  ...  0.0025 -0.0056 -0.0123 -0.0386
# 192610 -0.0306 -0.0331  0.0106 -0.0476  ... -0.0220 -0.0411 -0.0516 -0.0849
# 192611  0.0635  0.0729  0.0455  0.0166  ...  0.0652  0.0433  0.0224  0.0400
#
# [5 rows x 30 columns]

# %%
ind.index
# Out:
# Int64Index([192607, 192608, 192609, 192610, 192611, 192612, 192701, 192702,
#             192703, 192704,
#             ...
#             201803, 201804, 201805, 201806, 201807, 201808, 201809, 201810,
#             201811, 201812],
#            dtype='int64', length=1110)

# %%
ind.index = pd.to_datetime(ind.index, format="%Y%m").to_period('M')

# %%
ind.head()
# Out:
#           Food    Beer    Smoke   Games  ...   Rtail   Meals   Fin     Other
# 1926-07  0.0056 -0.0519  0.0129  0.0293  ...  0.0007  0.0187  0.0037  0.0520
# 1926-08  0.0259  0.2703  0.0650  0.0055  ... -0.0075 -0.0013  0.0446  0.0676
# 1926-09  0.0116  0.0402  0.0126  0.0658  ...  0.0025 -0.0056 -0.0123 -0.0386
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  ... -0.0220 -0.0411 -0.0516 -0.0849
# 1926-11  0.0635  0.0729  0.0455  0.0166  ...  0.0652  0.0433  0.0224  0.0400
#
# [5 rows x 30 columns]

# %%
ind.columns
# Out:
# Index(['Food ', 'Beer ', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth ',
#        'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
#        'Mines', 'Coal ', 'Oil  ', 'Util ', 'Telcm', 'Servs', 'BusEq', 'Paper',
#        'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin  ', 'Other'],
#       dtype='object')

# %%
ind.columns = ind.columns.str.strip()

# %%
ind.columns
# Out:
# Index(['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth',
#        'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
#        'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper',
#        'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other'],
#       dtype='object')

# %%
ind.shape
# Out:
# (1110, 30)

# %%
import edhec_risk_kit as erk

# %%
ind = erk.get_ind_retruns()
ind.shape
# Out:
# (1110, 30)

# %%
ind.head()
# Out:
#            Food    Beer   Smoke   Games  ...   Rtail   Meals     Fin   Other
# 1926-07  0.0056 -0.0519  0.0129  0.0293  ...  0.0007  0.0187  0.0037  0.0520
# 1926-08  0.0259  0.2703  0.0650  0.0055  ... -0.0075 -0.0013  0.0446  0.0676
# 1926-09  0.0116  0.0402  0.0126  0.0658  ...  0.0025 -0.0056 -0.0123 -0.0386
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  ... -0.0220 -0.0411 -0.0516 -0.0849
# 1926-11  0.0635  0.0729  0.0455  0.0166  ...  0.0652  0.0433  0.0224  0.0400
#
# [5 rows x 30 columns]

# %%
erk.drawdown(ind['Food'])["Drawdowns"].plot.line(figsize = (12,6))

# %%
erk.var_gaussian(ind[['Food', 'Smoke', 'Coal', 'Beer', 'Fin']], modified=True)
#Double square brackets mean that we are passing a list as an index
#Inner square bracket is to specify that it is a list 
#Outer square bracket is to specify that the list is an index to the dataframe
# Out:
# Food     0.061207
# Smoke    0.080292
# Coal     0.047359
# Beer     0.033881
# Fin      0.075199
# dtype: float64

# %%
erk.var_gaussian(ind, modified=True).sort_values().tail() #tail is used to see the last values of var
# Out:
# Carry    0.094527
# Meals    0.098403
# BusEq    0.099377
# Games    0.100701
# Mines    0.102782
# dtype: float64

# %%
erk.var_gaussian(ind, modified=True).sort_values().head() # head is to see the lowest var
# Out:
# Beer     0.033881
# Coal     0.047359
# Food     0.061207
# Telcm    0.064719
# Hshld    0.064886
# dtype: float64

# %%
erk.var_gaussian(ind, modified=True).sort_values().plot.bar()

# %%
erk.sharpe_ratio(ind['2000':], 0.03, 12).sort_values().plot.bar(title = "Industry Sharpe Ratios from 2000-2018", color='goldenrod', figsize=(12,5))

# %%
 er = erk.annualize_rets(ind['1995':'2000'], 12)

# %%
er.sort_values().plot.bar()

# %%
cov = ind['1995':'2000'].cov()

# %%
cov.shape
# Out:
# (30, 30)

# %%
cov  #covariance between the same element is the variance
# Out:
#            Food      Beer     Smoke  ...     Meals       Fin     Other
# Food   0.002287  0.002077  0.001757  ...  0.001085  0.001839  0.000898
# Beer   0.002077  0.004599  0.001143  ...  0.001634  0.002236  0.001196
# Smoke  0.001757  0.001143  0.007130  ...  0.000590  0.001117  0.001418
# Games  0.000701  0.001147  0.000296  ...  0.001383  0.002080  0.002088
# Books  0.000886  0.000765 -0.000099  ...  0.001026  0.001979  0.001283
# Hshld  0.001208  0.002447  0.000981  ...  0.001076  0.001652  0.001322
# Clths  0.001474  0.001415  0.000761  ...  0.002229  0.002699  0.001974
# Hlth   0.001105  0.001689  0.000877  ...  0.000900  0.001412  0.001099
# Chems  0.001253  0.001292  0.000687  ...  0.001425  0.002143  0.001832
# Txtls  0.001021  0.001721  0.000555  ...  0.001126  0.001789  0.001668
# Cnstr  0.001282  0.001945  0.001181  ...  0.001810  0.002331  0.001573
# Steel  0.000027  0.000131  0.000167  ...  0.000553  0.001851  0.003370
# ...
